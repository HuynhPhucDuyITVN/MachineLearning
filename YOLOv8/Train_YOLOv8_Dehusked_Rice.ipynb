# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/Dehusked_Rice/YOLOv8
# !pip install ultralytics
# Out:
# /content/drive/Shareddrives/Dehusked_Rice/YOLOv8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.4/756.4 kB 13.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# !yolo task=segment mode=train model= /content/drive/Shareddrives/Dehusked_Rice/yolov8s-seg.pt data= /content/drive/Shareddrives/Dehusked_Rice/DehuskedRice/final_data.yolov8/data.yaml epochs= 100 imgsz=800
# Out:
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=train model= /content/drive/Shareddrives/Dehusked_Rice/YOLOv8/runs/segment/train/weights/last.pt data= /content/drive/Shareddrives/Dehusked_Rice/DehuskedRice/final_data.yolov8/data.yaml epochs= 100 imgsz=800
# Out:
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=train model= /content/drive/Shareddrives/Dehusked_Rice/YOLOv8/runs/segment/train2/weights/last.pt data= /content/drive/Shareddrives/Dehusked_Rice/DehuskedRice/final_data.yolov8/data.yaml epochs= 100 imgsz=800
# Out:
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=train model= /content/drive/Shareddrives/Dehusked_Rice/YOLOv8/runs/segment/train3/weights/last.pt data= /content/drive/Shareddrives/Dehusked_Rice/DehuskedRice/final_data.yolov8/data.yaml epochs= 100 imgsz=800
# Out:
# Ultralytics YOLOv8.2.12 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=train model= /content/drive/Shareddrives/Dehusked_Rice/YOLOv8/runs/segment/train4/weights/last.pt data= /content/drive/Shareddrives/Dehusked_Rice/DehuskedRice/final_data.yolov8/data.yaml epochs= 100 imgsz=800
# Out:
# Ultralytics YOLOv8.2.13 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
